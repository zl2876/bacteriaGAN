# %% [markdown]
# # Install

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2337, done.
# remote: Total 2337 (delta 0), reused 0 (delta 0), pack-reused 2337
# Receiving objects: 100% (2337/2337), 8.09 MiB | 37.15 MiB/s, done.
# Resolving deltas: 100% (1499/1499), done.

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 686kB 24.4MB/s
# ...
#      |████████████████████████████████| 61kB 7.3MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp37-none-any.whl size=655251 sha256=3d5e2146a03c5bc32dd5be6c8987ccd3fe0b3ee82ba99998ed0e395355aa43c4
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp37-none-any.whl size=5713 sha256=4ed74c023250c80ce32abad85f5a1f7918fc8df729d92f1bd4d68923a7a8c30a
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# ...

# %% [markdown]
# # Dataset
#
# We uploaded the DIBaS dataset to a shared Google Drive folder.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
PATH_OF_DATA= '/content/gdrive/"My Drive"/"BMENE4460"/finalproject'
# !ls {PATH_OF_DATA}
# Out:
# A  AB  B

# %%
# !python ./datasets/combine_A_and_B.py --fold_A /content/gdrive/"My Drive"/"BMENE4460"/finalproject/A --fold_B /content/gdrive/"My Drive"/"BMENE4460"/finalproject/B --fold_AB /content/gdrive/"My Drive"/"BMENE4460"/finalproject/AB --num_imgs 351
# Out:
# [fold_A] =  /content/gdrive/My Drive/BMENE4460/finalproject/A
# [fold_B] =  /content/gdrive/My Drive/BMENE4460/finalproject/B
# [fold_AB] =  /content/gdrive/My Drive/BMENE4460/finalproject/AB
# [num_imgs] =  351
# [use_AB] =  False
# [no_multiprocessing] =  False
# split = test, use 107/107 images
# split = test, number of images = 107
# split = train, use 241/241 images
# split = train, number of images = 241

# %% [markdown]
# # Training
#
# -   `python train.py --dataroot /content/gdrive/"My Drive"/finalproject/AB --name dibas_pix2pix --model pix2pix --direction BtoA`
#
# Change the `--dataroot` and `--name` to your own dataset's path and model's name. Use `--gpu_ids 0,1,..` to train on multiple GPUs and `--batch_size` to change the batch size. Add `--direction BtoA` if you want to train a model to transfrom from class B to A.

# %%
# !python train.py --dataroot /content/gdrive/"My Drive"/"BMENE4460"/finalproject/AB --name dibas_pix2pix --model pix2pix #--direction BtoA #--num_samples
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /content/gdrive/My Drive/BMENE4460/finalproject/AB	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                 lambda_L1: 100.0
# ...

# %% [markdown]
# # Testing
#
# -   `python test.py --dataroot ./datasets/facades --direction BtoA --model pix2pix --name facades_pix2pix`
#
# Change the `--dataroot`, `--name`, and `--direction` to be consistent with your trained model's configuration and how you want to transform images.
#
# > from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix:
# > Note that we specified --direction BtoA as Facades dataset's A to B direction is photos to labels.
#
# > If you would like to apply a pre-trained model to a collection of input images (rather than image pairs), please use --model test option. See ./scripts/test_single.sh for how to apply a model to Facade label maps (stored in the directory facades/testB).
#
# > See a list of currently available models at ./scripts/download_pix2pix_model.sh

# %%
# !ls checkpoints/
# Out:
# dibas_pix2pix

# %%
# !python test.py --dataroot /content/gdrive/"My Drive"/"BMENE4460"/finalproject/AB --model pix2pix --name dibas_pix2pix

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/dibas_pix2pix/test_latest/images/Veionella_0018_fake_B.png')
plt.imshow(img)

# %%
# !zip -r /content/gdrive/"My Drive"/"BMENE4460"/file.zip /content/pytorch-CycleGAN-and-pix2pix/results/dibas_pix2pix/test_latest/images
